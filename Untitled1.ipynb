# %% [markdown]
# 1 Explain the key feature of python that make it popular choice for programing
# 1. Simple and easy to learn:  python has a clear and easy to read syntax, its code closely resembles english, reducing the learning curve.
# 2. Interpreted language: python execute code line by line which make debugging easier
# 3. versatile and general purpose: python is used for wide range of applicationsincluding web development, data analysis, artificial intelligence.
# 4. extensive standard library: python comes with vast standard libraries that provides modules and functions for task like web development.
# 5. Large community and support: python has massive global community.
# 6. Dynamic typing: In python you need not to declare data types explicitely. This feature simplifies coding.
#
# 2.Explain the role of predefined keywords in python and provide examples of how they are used.
#
#    In python, predefined keywords also called reserved keywords are words that have specific meaning and purpose in the language's syntax. they are reserved for specific functionality. for Eg if, else, elif: used for conditional statements
# if X>10:
# print("X is greater than 10")
# elif X==10:
# print("X is equal to 10")
# else:
# ("X is less than 10")
#
# 3.compare and contrast mutable and immutable objects in python with examples.
#
# In python objects are classified as mutable and immutable depending on whether their state ie their data or content can be changed after they are created. this distinction is important when working with  variables, functions and data structures.
#
# Mutable objects: Mutable objects are those whose value can be changed or modified after the object is created, without creating new object.
#  lists(list)
# Dictionaries(dict)
# Sets(set)
# my_list = [1,2,3]
# print(my_list)
# [1,2,3]
# my_list[0]=10
# print(my_list)
# [10,2,3]
# #changing the first element
# the value inside my_list was changed, but the object my_list itself was not replaced. this is the key feature of mutable objects.
#
# Immutable objects are thise whose value can not be changed after the object is created. if you attempt to modify an immutable object, a new object is created
# Floats(float)
# strings(str)
# my_string= "Hello"
# print(my_string)
# "Hello"
# my_string[0]='a'
# this will raise a Type error since strings are immutable.
#
# 4. Discuss the different types of operators in python and provide examples of how they are used.
#
# In python operators are special keywords or symbols used to perform operations on variable and values.
# several types of operators are as below
#
# 1. Arithmetic operators: Arithmetic operatiors are used to perform mathematical operations.
# addition: +
#  5+3
# 8
# Subtraction: -
#  5-3
# 2
# Multiplication: *
#  5*3
# 15
# Division: /
#  5/3
#  1.6667
# Floor division
#  5//3
# 1
# (discards remainder)
#
# 2. Comparison (Relational operators): comparison operators compare two values and return eitherr true or false.
#  equal to: ==
#  5==5
#  True
#  Not equal to: !=
#   5!=3
#   True
#   Less than: <
#   5 < 3
#  False
#
# 3. Logical operators: logical operators are used to combine conditional statements.
# Logical AND: and
# True and False
# False
# Logical OR: or
# True or False
# True
#
# 4. Assignment operator: Assignment operators are used to assign values to variables
# Assign : =
# X=10
# X+=5
# 15
#
# 5. Bitwise operators: Bitwise operators are perform operations on binary numbers
# AND &
# 5&3
# 1
# XOR: ^
# 5^3
# 6
# 6. Identity operators: identity operators are used to compare objects and check if they refer to the same memorylocation.
# Return True if both variables point to the same objects
# is
# X is Y
# True/ False
# 7. Membership operators: Membership operators are used to check whether a value or variable is present in a sequence ( eg. string, list, tuple)
# Return True if a value is found in the sequence
# in
# 'a' in 'apple'
# True
# 8. Ternary (conditional operator): the ternary operator provide a sharthand way to write an if-else condition in a single line.
# Return xif the condition is true, else return y
# x if condition else y
# 'Even' if x % 2==0
# else
# 'odd'
# 'odd' if x is 3
#
# 5. Explain the concept of type casting in python with examples
# Typecating is a process of converting variable from one data type to another. In python this can be done manually (explicit typecasting) using python,s built in function.or automatically (implicit typecasting) when python convert data types in certain operators.
# Explicit typecasting: this is required when automatic conversion doesnt take place or when you want to force a specific type conversion
# convert a vlaue to an integer
# int()
# convert a value to float
# float()
# convert a value to string
# str()
#
# Implicit Typecasting: This usally happens when mixing data types in expressions and python convert the smaller data type into the 'larger' one to avoid data loss.
# x=10
# y=5.5
# result=x+y
# print(result)
# 13.5
# print(type(result))
# #<class'float'>
#
# 6.how do conditional statements work in python? illustrate with examples.
# Conditional statements are used to perform different action based on certain conditions
# conditionaql statements in pythos are as follow
# 1 if statement
# if-else statement
# if-eliif statement
# nested if statement
# These statements allow the execution of a blockof code only when a particular condition is true.
# e.g
# x=10
# if x>5:
# print("x is greater than 5")
# x is greater than 5
# the if statement check a condition and if its true execute the block of code inside the if statement. if the condition is false, the code inside the block is skipped.
#
# 7 Describe the different types of loopsin python and their use cases with examples.
# loops are used to repeatedly execute a block of code as long as the condition is true or for a certain number of iterations. python provide two main tyoe of loops
# 1. for loop
# for loop is used to iterate over a seqence like loist, tuple, string
# # fruits=["apple","banana","cherry"]
# for fruits in fruits:
# apple
# banana
# cherry
#
#
# 2. while loop
# a while loop keeps executing the code block as long as the condition remains true. the condition is checked beforev each iteration
# count=5
# while count>0:
# print("counting down:", count)
# count-= 1
# counting down: 5
# counting down: 4
# counting down: 3
# counting down: 2
# counting down: 1
